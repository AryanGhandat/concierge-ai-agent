# %% [markdown]
# # Concierge AI — Notebook
# Run this notebook on Kaggle or Colab. Set the OPENAI_API_KEY environment variable for OpenAI-powered mode, otherwise the notebook uses the rule-based fallback.

# %%
# Install dependencies (uncomment to run)
# !pip install openai pandas python-dateutil tqdm

# %%
from agent import run_agent

run_agent('emails.csv', 'email_agent_output.csv')

import pandas as pd
pd.read_csv('email_agent_output.csv')
